# %%
import pandas as pd

# %%
data = pd.read_csv('census.csv')

# %%
data.head()
# Out:
#    Unnamed: 0.4  Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  age  \
# 0             0             0             0             0           0   39
# 1             1             1             1             1           1   50
# 2             2             2             2             2           2   38
# 3             3             3             3             3           3   53
# 4             4             4             4             4           4   28
#
#           workclass   fnlgt  education   education-num      marital-status  \
# 0         State-gov   77516  Bachelors              13       Never-married
# 1  Self-emp-not-inc   83311  Bachelors              13  Married-civ-spouse
# 2           Private  215646    HS-grad               9            Divorced
# 3           Private  234721       11th               7  Married-civ-spouse
# 4           Private  338409  Bachelors              13  Married-civ-spouse
#
#           occupation   relationship   race     sex   capital-gain  \
# 0       Adm-clerical  Not-in-family  White    Male           2174
# 1    Exec-managerial        Husband  White    Male              0
# 2  Handlers-cleaners  Not-in-family  White    Male              0
# 3  Handlers-cleaners        Husband  Black    Male              0
# 4     Prof-specialty           Wife  Black  Female              0
#
#     capital-loss   hours-per-week  native-country  salary
# 0              0               40   United-States   <=50K
# 1              0               13   United-States   <=50K
# 2              0               40   United-States   <=50K
# 3              0               40   United-States   <=50K
# 4              0               40            Cuba   <=50K

# %%
data = data.applymap(lambda x: x.strip().replace(" ", "") if type(x) == str else x)
data.rename(columns=lambda x: x.strip(), inplace=True)

# %%
data.to_csv('/Users/philipherp/Documents/Udacity/Machine_Learning_DevOps/mldo_project_3/starter/data/census.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0.4    32561 non-null  int64
#  1   Unnamed: 0.3    32561 non-null  int64
#  2   Unnamed: 0.2    32561 non-null  int64
#  3   Unnamed: 0.1    32561 non-null  int64
#  4   Unnamed: 0      32561 non-null  int64
#  5   age             32561 non-null  int64
#  6   workclass       32561 non-null  object
#  7   fnlgt           32561 non-null  int64
#  8   education       32561 non-null  object
#  9   education-num   32561 non-null  int64
#  10  marital-status  32561 non-null  object
#  11  occupation      32561 non-null  object
#  12  relationship    32561 non-null  object
#  13  race            32561 non-null  object
#  14  sex             32561 non-null  object
#  15  capital-gain    32561 non-null  int64
#  16  capital-loss    32561 non-null  int64
#  17  hours-per-week  32561 non-null  int64
#  18  native-country  32561 non-null  object
#  19  salary          32561 non-null  object
# dtypes: int64(11), object(9)
# memory usage: 5.0+ MB
